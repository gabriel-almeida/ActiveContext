,'Random' : [0.829588049493,0.826162917994,0.799960006919,0.812712007157,0.825245764475,0.7819271784,0.800362974168,0.839343007396,0.821078003544,0.837231190812,0.856877463592,0.788160569653,0.802623902644,0.847141684399,0.782154983413,0.814973672713,0.873710390827,0.827954058403,0.820714103411,0.816121457848,0.781062312515,0.821982142841,0.836354962434,0.793927979323,0.857145457854,0.776926345019,0.805515690829,0.785691182172,0.819784443968,0.801941023899]
,'Cramer Deviation' : [0.819036045121,0.823842274777,0.785137494135,0.801152202196,0.823563836284,0.780146994082,0.795603001408,0.83458590294,0.819088916617,0.826157967752,0.858460561958,0.792662622781,0.796986941613,0.846005650318,0.779950921501,0.813227746242,0.874737618821,0.820273352157,0.811692626493,0.818608037842,0.765497411095,0.822483681718,0.842938731023,0.780050447656,0.855776320734,0.784152647857,0.814456895425,0.785758795868,0.820710401922,0.806796822012]
,'Largest Deviation' : [0.819036045121,0.823842274777,0.785137494135,0.801152202196,0.823563836284,0.780146994082,0.795603001408,0.83458590294,0.819088916617,0.826157967752,0.858460561958,0.792662622781,0.796986941613,0.846005650318,0.779950921501,0.813227746242,0.874737618821,0.820273352157,0.811692626493,0.818608037842,0.765497411095,0.822483681718,0.842938731023,0.780050447656,0.855776320734,0.784152647857,0.814456895425,0.785758795868,0.820710401922,0.806796822012]}

}

# %%
#dictionary = {}
with open('results3.tsv') as f:
    for line in f.readlines()[1:]:
        fields = line.strip().split('\t')
        
        n_context = int(fields[0])
        algo = fields[1]
        results = [ float(i) for i in fields[2:]]
        
        if n_context not in dictionary:
            dictionary[n_context] = {}
        results_by_contexts = dictionary[n_context]
        
        results_by_contexts[algo] = results
        
print(np.mean(dictionary[1]['Cramer Deviation']))
# Out:
# 0.812611214139

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

algo_names = ['All Contexts', 'Cramer Deviation', 'Largest Deviation', 'Random']
possible_contexts = [1,2,3,4, 5, 6, 7, 8]

y_min = 0.8
x_individual = 1
x_group = 2

y_axis = []
x_axis = []
actual_x = 0
centered_xlabel = [ ((x_individual)*len(algo_names) - 1)/2.0 + (i-1)*(x_group +( x_individual*len(algo_names))) for i in range(1,5)]

for n_context in possible_contexts:
    results_by_algo = dictionary[n_context]
    for algo in algo_names:
        y_axis  += [np.average(results_by_algo[algo]) - y_min]
        x_axis += [actual_x]
        
        actual_x += x_individual
    actual_x += x_group
    
plt.bar(x_axis, y_axis, bottom=y_min,  align='center', color='krbc')
    
legend_meaning = [
    mpatches.Patch(color='k', label='All Contexts'),
    mpatches.Patch(color='r', label='Cramer Deviation'),
    mpatches.Patch(color='b', label='Largest Deviation'),
    mpatches.Patch(color='c', label='Random'),
]
plt.legend(handles=legend_meaning)

plt.title('Results')
plt.xticks(centered_xlabel, possible_contexts )
plt.xlabel('Numer of contexts')
plt.ylabel('MAE')

plt.show()
